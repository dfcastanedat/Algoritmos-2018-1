# %%
import random
def randomPerm(n):
    v=[]
    for i in range(n):
        v.append(i+1)
    for i in range(len(v)-1):
        j = random.randint(i, len(v)-1)
        aux = v[i]
        v[i] = v[j]
        v[j] = aux
    return v

def isortSteps(a):
    v = []
    for i in range(len(a)):
        v.append(a[i])
        
    steps = 0
    for i in range(1,len(v)):
        x = v[i]
        j = i-1
        while (j > -1) and (v[j] > x):
            v[j+1] = v[j]
            j = j -1
            steps = steps + 3
        steps = steps + 1
        v[j+1] = x
        steps = steps + 4
    steps = steps + 1
    return steps


n = 50
runs = 10000
arr = []
sum = 0
min = n**3
max = 0
for i in range(runs):
    t = isortSteps(randomPerm(n))
    arr.append(t)
    if t < min :
       min = t
    if t > max :
       max = t
    sum = sum + t
print 'Mejor tiempo teorico, ' + str(5*n - 4) 
print 'Pero tiempo teorico,' + str((3.0/2.0)*n**2 + (7.0/2.0)*n - 4)
print 'Tiempo promedio teorico,' + str((3.0/4.0)*n**2 + (17.0/4.0)*n - 4)
print 'Mejor tiempo experimenal, ' + str(min)
print 'Peor tiempo experimental,' + str(max)
print 'Tiempo promedio experimental,' + str(sum/runs)
# Out:
# Mejor tiempo teorico, 246
# Pero tiempo teorico,3921.0
# Tiempo promedio teorico,2083.5
# Mejor tiempo experimenal, 1422
# Peor tiempo experimental,2793
# Tiempo promedio experimental,2083

# %%
import numpy as np
numero = np.zeros((10000))
for i in range(10000):
    numero[i] = i

# %%
import matplotlib.pyplot as plt
plt.plot(numero, arr, 'b^')
plt.ylabel('#de movimientos')
plt.xlabel('n')
plt.show()

plt.hist(arr, bins='auto', color="black")
plt.title("Histograma usando numeros aleatoros para n = 50")
plt.show()
